# %%
import pandas as pd

df = pd.read_csv('stud.csv')

print(df.to_string())
# Out:
#    rollno     Name  Marks
# 0       1     Nitu     56
# 1       2     Ajay     67
# 2       3    Ravi      80
# 3       4   Mamata     76
# 4       5   Pankaj     45
# 5       6  Thakur      34
# 6       7  Shakshi     78
# 7       8  Archana     55
# 8       9     Neha     78
# 9      10   Rajesh     45

# %%
df.head()
# Out:
#    rollno    Name  Marks
# 0       1    Nitu     56
# 1       2    Ajay     67
# 2       3   Ravi      80
# 3       4  Mamata     76
# 4       5  Pankaj     45

# %%
df.shape
# Out:
# (10, 3)

# %%
import numpy as np

# %% [raw]
# arr = np.arr([12,23,44,55])

# %% [raw]
# print(arr)

# %%
import numpy as np

# %%
arr = np.array([12,23,44,55])
print(arr)
# Out:
# [12 23 44 55]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(np.__version__)
# Out:
# 1.26.4

# %%
print(pd.__version__)
# Out:
# 2.2.2
